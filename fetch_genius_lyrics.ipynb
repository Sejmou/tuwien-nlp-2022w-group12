# %% [markdown]
# # Using Genius API to obtain full-text lyrics and language information for our song dataset

# %%
import pandas as pd
import numpy as np
from lyricsgenius import Genius
from dotenv import load_dotenv
import os

# %%
data_dir = "data"

# %%
no_lyric_data = pd.read_csv(os.path.join(data_dir, "msd_mxm+tagtraum.csv"))
no_lyric_data
# Out:
#                   msd_tid  mxm_tid                                   title  \
# 0      TRAAAED128E0783FAB  2516445                         It's About Time
# 1      TRAAAEF128F4273421  3759847                         Something Girls
# 2      TRAAAGF12903CEC202  5493388                                 Små ord
# 3      TRAAAHZ128E0799171  1619153                        The One and Only
# 4      TRAAARJ128F9320760  1422131                              Pink World
# ...                   ...      ...                                     ...
# 83187  TRZZSXX128F93262C9  2736386  My Mother Was a Chinese Trapeze Artist
# 83188  TRZZUTD12903CADD68  8852681                   Solo Dolo (Nightmare)
# 83189  TRZZWEM128F428BD9A  1441760                       Operator's Manual
# 83190  TRZZXOQ128F932A083  4292070                                   After
# 83191  TRZZZZD128F4236844  2466899                                Mr. Soul
#
#                   artist genre  is_test
# 0           Jamie Cullum  Jazz        0
# 1               Adam Ant  Rock        0
# 2      Halvdan Sivertsen   Pop        0
# 3             Snoop Dogg   Rap        0
# 4       Planet P Project  Rock        0
# ...                  ...   ...      ...
# 83187             Tarkio  Rock        1
# 83188           Kid Cudi   Rap        1
# 83189          Buzzcocks  Punk        1
# 83190          Riverside  Rock        1
# 83191               Rush  Rock        1
#
# [83192 rows x 6 columns]

# %%
load_dotenv()
genius = Genius()
genius.verbose = False # Turn off status messages
genius.remove_section_headers = True # Remove section headers (e.g. [Chorus]) from lyrics when searching

# %% [markdown]
# ## Defining function for fetching lyrics

# %% [markdown]
# The following function will be used in conjuction with the `apply()` function of the dataframe to fetch lyrics for every row of the dataset:

# %%
def get_lyrics(row):
  result = genius.search_song(row.title, row.artist, get_full_info=True)
  if result is not None:
    data = result.to_dict()
    return pd.Series([row.msd_tid, data["language"], data["lyrics"]], index=['msd_tid', 'language', 'lyrics'])
  else:
    return pd.Series([row.msd_tid, None, None], index=['msd_tid', 'language', 'lyrics'])

# %% [markdown]
# a quick demo:

# %%
lyrics = no_lyric_data[:3].apply(get_lyrics, axis=1, result_type="expand")

# %%
lyrics
# Out:
#               msd_tid language  \
# 0  TRAAAED128E0783FAB       en
# 1  TRAAAEF128F4273421       en
# 2  TRAAAGF12903CEC202       no
#
#                                               lyrics
# 0  It’s About Time Lyrics\nWalking down to the wa...
# 1  Something Girls LyricsEvery girl is a somethin...
# 2  Små ord LyricsSmå ord, mjuke ord\nEt øre mot e...

# %%
np.array_split(no_lyric_data, 200)[0]
# Out:
#                 msd_tid  mxm_tid                                title  \
# 0    TRAAAED128E0783FAB  2516445                      It's About Time
# 1    TRAAAEF128F4273421  3759847                      Something Girls
# 2    TRAAAGF12903CEC202  5493388                              Små ord
# 3    TRAAAHZ128E0799171  1619153                     The One and Only
# 4    TRAAARJ128F9320760  1422131                           Pink World
# ..                  ...      ...                                  ...
# 411  TRADCJT12903CB102B  3837070  Work, Work, Work (Pub, Club, Sleep)
# 412  TRADCNP12903CFDBFA  8115972                  Little Heartwrecker
# 413  TRADDAQ12903CBBEA4  9977714                            Invisible
# 414  TRADDBB128F92DFBE5  7726015                                 Fall
# 415  TRADDCI128F42B2621  1585354                             Love Gun
#
#                 artist    genre  is_test
# 0         Jamie Cullum     Jazz        0
# 1             Adam Ant     Rock        0
# 2    Halvdan Sivertsen      Pop        0
# 3           Snoop Dogg      Rap        0
# 4     Planet P Project     Rock        0
# ..                 ...      ...      ...
# 411          The Rakes     Rock        0
# 412     Dierks Bentley  Country        0
# 413   The Letter Black     Rock        0
# 414      The Saturdays      Pop        0
# 415      Hayseed Dixie  Country        0
#
# [416 rows x 6 columns]

# %% [markdown]
# ## Split dataframe into chunks

# %% [markdown]
# Let's split the dataframe into chunks of size 100.

# %%
len(no_lyric_data)
# Out:
# 83192

# %%
first_83100 = no_lyric_data[:83100]
rest = no_lyric_data[83100:]

chunks = np.array_split(first_83100, 830)
chunks.append(rest)
chunks
# Out:
# [                msd_tid  mxm_tid                   title               artist  \
#  0    TRAAAED128E0783FAB  2516445         It's About Time         Jamie Cullum
#  1    TRAAAEF128F4273421  3759847         Something Girls             Adam Ant
#  2    TRAAAGF12903CEC202  5493388                 Små ord    Halvdan Sivertsen
#  3    TRAAAHZ128E0799171  1619153        The One and Only           Snoop Dogg
#  4    TRAAARJ128F9320760  1422131              Pink World     Planet P Project
#  ..                  ...      ...                     ...                  ...
#  96   TRAARXB128F92FA0BF  2505393  Blackmail the Universe             Megadeth
#  97   TRAARXD12903D0CF24  1599155           Born to Booze  Black Label Society
#  98   TRAASHC128F427ED9F  5662996               Up to You           David Kitt
#  99   TRAASTP128F4294FD9  1653532             Lonely Mile       Rory Gallagher
#  100  TRAATIP12903CB1B56  9465406             Clear Skies                Keane
#
#       genre  is_test
#  0     Jazz        0
#  1     Rock        0
#  2      Pop        0
#  3      Rap        0
#  4     Rock        0
#  ..     ...      ...
#  96   Metal        0
#  97   Metal        0
#  98    Rock        0
#  99    Rock        0
#  100   Rock        0
#
#  [101 rows x 6 columns],
#                  msd_tid   mxm_tid                     title  \
#  101  TRAATIU128F4291A84   1315548         Shadows That Move
#  102  TRAATKF128E0786B4B   1773477                    Desire
#  103  TRAATLN128F425399A    637751                 Questions
#  104  TRAATMI128F9366CA1    821465              Vilda vindar
#  105  TRAATPA128F146753C    920755             Teacher's Pet
#  ..                  ...       ...                       ...
#  197  TRABMIY128F426EA8F   4863608                Seven Seas
#  198  TRABMPO12903CA4BDC    926628  He Thinks He'll Keep Her
#  199  TRABNAL128F9327309  12554737         The Hardest Thing
#  200  TRABNDS128F93236DD   7740463    What's the Matter Baby
#  201  TRABNEX128F92C9DEA   6065922                Knocked Up
#
#                      artist    genre  is_test
#  101               Mastodon    Metal        0
#  102          Holly Valance      Pop        0
#  103          Youth Brigade     Punk        0
#  104             Kalle Baah   Reggae        0
#  105                Extreme     Rock        0
#  ..                     ...      ...      ...
#  197               Babyface      RnB        0
#  198  Mary Chapin Carpenter  Country        0
#  199           Тоше Проески     Rock        0
#  200            Ellen Foley     Rock        0
#  201          Kings of Leon     Rock        0
#
#
#  [100 rows x 6 columns],
#                    msd_tid  mxm_tid                                   title  \
#  83100  TRZSCUL12903CBDB7D   966331                 The Sea and a Lifesaver
#  83101  TRZSEAS128F14534C5  4369969                 Don't Do Me Any Favours
#  83102  TRZSFWI128F425ADAA  6624613                               Dynamite!
#  83103  TRZSKXH12903CCE22D  1180210                 Companion (Lay Me Down)
#  83104  TRZSLZF12903CE3F6B   674945                          We Are the One
#  ...                   ...      ...                                     ...
#  83187  TRZZSXX128F93262C9  2736386  My Mother Was a Chinese Trapeze Artist
#  83188  TRZZUTD12903CADD68  8852681                   Solo Dolo (Nightmare)
#  83189  TRZZWEM128F428BD9A  1441760                       Operator's Manual
#  83190  TRZZXOQ128F932A083  4292070                                   After
#  83191  TRZZZZD128F4236844  2466899                                Mr. Soul
#
#                         artist genre  is_test
#  83100                 Piebald  Rock        1
#  83101                    a-ha   Pop        1
#  83102  Sly & The Family Stone   RnB        1
#  83103        Wide Mouth Mason  Rock        1
#  83104            The Avengers  Punk        1
#  ...                       ...   ...      ...
#  83187                  Tarkio  Rock        1
#  83188                Kid Cudi   Rap        1
#  83189               Buzzcocks  Punk        1
#  83190               Riverside  Rock        1
#  83191                    Rush  Rock        1
#
#  [92 rows x 6 columns]]

# %% [markdown]
# ## Fetch lyrics for each chunk, write to file

# %% [markdown]
# We'll use `swifter` to (hopefully) make the processing of the chunks faster with parallelization and other optimisations.

# %%
pip install swifter
# Out:
# Requirement already satisfied: swifter in /home/sejmou/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: parso>0.4.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (0.8.3)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (2022.5.0)
# Requirement already satisfied: pandas>=1.0.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (1.4.2)
# Requirement already satisfied: cloudpickle>=0.2.2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (2.0.0)
# Requirement already satisfied: tqdm>=4.33.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (4.64.0)
# Requirement already satisfied: bleach>=3.1.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (4.1.0)
# Requirement already satisfied: psutil>=5.6.6 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (5.9.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from swifter) (7.6.5)
# Requirement already satisfied: packaging in /home/sejmou/anaconda3/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (21.3)
# Requirement already satisfied: six>=1.9.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /home/sejmou/anaconda3/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: partd>=0.3.10 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: fsspec>=0.6.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.3.0)
# Requirement already satisfied: numpy>=1.18 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.5)
# Requirement already satisfied: nbformat>=4.2.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (8.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (1.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1)
# Requirement already satisfied: nest-asyncio in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: stack-data in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: decorator in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (61.2.0)
# Requirement already satisfied: pickleshare in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: backcall in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.20)
# Requirement already satisfied: pyzmq>=13 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.4.0)
# Requirement already satisfied: fastjsonschema in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from packaging->bleach>=3.1.1->swifter) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->swifter) (2022.1)
# Requirement already satisfied: locket in /home/sejmou/anaconda3/lib/python3.9/site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sejmou/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.11)
# Requirement already satisfied: terminado>=0.8.3 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/sejmou/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.13.1)
# Requirement already satisfied: jinja2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: argon2-cffi in /home/sejmou/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: beautifulsoup4 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: defusedxml in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.13)
# Requirement already satisfied: testpath in /home/sejmou/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/sejmou/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.15.0)
# Requirement already satisfied: pycparser in /home/sejmou/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /home/sejmou/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.3.1)
# Requirement already satisfied: asttokens in /home/sejmou/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.5)
# Requirement already satisfied: pure-eval in /home/sejmou/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: executing in /home/sejmou/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Create a folder where we write the chunks to:

# %%
lyric_chunks_folder_path = os.path.join(data_dir, "lyric_chunks")
if not os.path.exists(lyric_chunks_folder_path):
  os.mkdir(lyric_chunks_folder_path)

# %%
import swifter

for i, chunk in enumerate(chunks):
  print(f"processing chunk {i} (indices {chunk.index[0]}-{chunk.index[-1]})")
  lyrics = chunk.apply(get_lyrics, axis=1, result_type="expand")
  lyrics.to_json(os.path.join(lyric_chunks_folder_path, f"chunk_{i}_({chunk.index[0]}-{chunk.index[-1]}).json"), orient="index")
# Out:
# processing chunk 0 (indices 0-100)
# Pandas Apply:   0%|          | 0/101 [00:00<?, ?it/s]
# processing chunk 1 (indices 101-201)
# Pandas Apply:   0%|          | 0/101 [00:00<?, ?it/s]
# processing chunk 2 (indices 202-302)
# Pandas Apply:   0%|          | 0/101 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1376 try:
# -> 1377     response.begin()
#    1378 except ConnectionError:
#
# File ~/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File ~/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~/anaconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~/anaconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/lyricsgenius/api/base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     577 elif isinstance(e, ReadTimeoutError):
# --> 578     raise ReadTimeout(e, request=request)
#     579 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# /home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb Cell 22 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> for i, chunk in enumerate(chunks):
#       <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a>   print(f"processing chunk {i} (indices {chunk.index[0]}-{chunk.index[-1]})")
# ----> <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a>   lyrics = chunk.swifter.apply(get_lyrics, axis=1, result_type="expand")
#       <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a>   lyrics.to_json(os.path.join(lyric_chunks_folder_path, f"chunk_{i}_({chunk.index[0]}-{chunk.index[-1]}).json"), orient="index")
#
# File ~/anaconda3/lib/python3.9/site-packages/swifter/swifter.py:451, in DataFrameAccessor.apply(self, func, axis, raw, result_type, args, **kwds)
#     448 else:
#     449     apply_func = self._obj.apply
# --> 451 return apply_func(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#
# File ~/anaconda3/lib/python3.9/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# File ~/anaconda3/lib/python3.9/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# /home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb Cell 22 in get_lyrics(row)
#       <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> def get_lyrics(row):
# ----> <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a>   result = genius.search_song(row.title, row.artist, get_full_info=True)
#       <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a>   if result is not None:
#       <a href='vscode-notebook-cell:/home/sejmou/Repos/Uni/NLP/tuwien-nlp-2022w-group12/fetch_genius_lyrics.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a>     data = result.to_dict()
#
# File ~/anaconda3/lib/python3.9/site-packages/lyricsgenius/genius.py:401, in Genius.search_song(self, title, artist, song_id, get_full_info)
#     399 else:
#     400     search_term = "{s} {a}".format(s=title, a=artist).strip()
# --> 401     search_response = self.search_all(search_term)
#     402     result = self._get_item_from_search_response(search_response,
#     403                                                  title,
#     404                                                  type_="song",
#     405                                                  result_type="title")
#     407 # Exit search if there were no results returned from API
#     408 # Otherwise, move forward with processing the search results
#
# File ~/anaconda3/lib/python3.9/site-packages/lyricsgenius/api/public_methods/search.py:210, in SearchMethods.search_all(self, search_term, per_page, page)
#     188 """Searches all types.
#     189
#     190 Including: albums, articles, lyrics, songs, users and
#    (...)
#     207
#     208 """
#     209 endpoint = 'multi'
# --> 210 return self.search(search_term, per_page, page, endpoint)
#
# File ~/anaconda3/lib/python3.9/site-packages/lyricsgenius/api/public_methods/search.py:45, in SearchMethods.search(self, search_term, per_page, page, type_)
#      41     path = 'search/' + type_
#      42 params = {'q': search_term,
#      43           'per_page': per_page,
#      44           'page': page}
# ---> 45 return self._make_request(path, params_=params, public_api=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/lyricsgenius/api/base.py:84, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      82     error = "Request timed out:\n{e}".format(e=e)
#      83     if tries > self.retries:
# ---> 84         raise Timeout(error)
#      85 except HTTPError as e:
#      86     error = get_description(e)
#
# Timeout: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
